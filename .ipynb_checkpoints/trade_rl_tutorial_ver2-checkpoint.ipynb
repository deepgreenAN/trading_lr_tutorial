# %% [markdown]
# # 強化学習で株取引　その１

# %% [markdown]
# 今回は環境の作成もかねて，一つの銘柄の取引を強化学習で行う．予測とはアルゴリズムを分離するため，未来の株価も含めるように調整する．

# %%
import sys
sys.path.append(r"E:\trading_rl_tutorial\pfrl")
sys.path.append(r"E:\システムトレード入門\trade_system_git_workspace")

# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from numpy.random import RandomState
import pandas as pd
from tqdm.notebook import tqdm
from collections import namedtuple
import collections
from copy import deepcopy
import matplotlib.pyplot as plt

# %%
import gym
from gym import spaces, logger
from gym.utils import seeding

# %%
import datetime
from pytz import timezone

# %%
from pathlib import Path

# %%
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
import pfrl

# %%
from get_stock_price import StockDatabase

# %%
from utils import middle_sample_type_with_check, get_previous_datetime, get_next_workday_jp
from utils import extract_workdays_intraday_jp_index, extract_workdays_intraday_jp

# %%
from visualize_trading_process_ver1 import plot_trading_process_matplotlib, plot_trading_process_bokeh

# %% [markdown]
# ### データベース

# %%
db_path = Path("E:/システムトレード入門/trade_system_git_workspace/db/stock_db") / Path("stock.db")
stock_db = StockDatabase(db_path)

# %%
stock_list = ["4755","9984","6701","7203","7267"]
stock_db.stock_in(stock_list)
# Out:
# array([ True,  True,  True,  True,  True])

# %%
stock_db.stock_timestamp(stock_list)
# Out:
#                 min_datetime               max_datetime column_name
# 0  2020-11-02 00:00:00+00:00  2020-12-21 05:59:00+00:00        4755
# 1  2020-11-02 00:00:00+00:00  2020-12-21 05:59:00+00:00        9984
# 2  2020-11-02 00:00:00+00:00  2020-12-21 05:59:00+00:00        6701
# 3  2020-11-02 00:00:00+00:00  2020-12-21 05:59:00+00:00        7203
# 4  2020-11-02 00:00:00+00:00  2020-12-21 05:59:00+00:00        7267

# %% [markdown]
# ### 利用するデータ

# %%
jst_timezone = timezone("Asia/Tokyo")
start_datetime = jst_timezone.localize(datetime.datetime(2020,11,1,0,0,0))
end_datetime = jst_timezone.localize(datetime.datetime(2020,12,1,0,0,0))
#end_datetime = get_next_workday_jp(start_datetime, days=11)  # 営業日で一週間(5日間)

#stock_names = "4755"
#stock_names = "9984"
stock_names = "6502"
#stock_names = ["6502","4755"]
#stock_list = ["4755","9984","6701","7203","7267"]

stock_df = stock_db.search_span(stock_names=stock_names, 
                                start_datetime=start_datetime,
                                end_datetime=end_datetime,
                                freq_str="T",
                                to_tokyo=True
                               )

use_ohlc="Close"

# %% [markdown]
# #### 利用するデータの描画

# %%
if isinstance(stock_names, str):
    stock_names = [stock_names]

for stock_name in stock_names:
    fig, ax=plt.subplots()
    column_name = use_ohlc + "_" + stock_name
    intraday_stock_df = extract_workdays_intraday_jp(stock_df)
    stock_price_array = intraday_stock_df.loc[:,column_name].copy().values
    x = np.arange(0,len(stock_price_array))
    ax.plot(x,stock_price_array)

# %% [markdown]
# ### 環境クラス

# %% [markdown]
# #### 状態クラス (namedtuple)

# %%
field_list = ["cash", "unit_number", "mean_cost_price", "price_array"]
StockStateBase = namedtuple("StockStateBase", field_list)

class StockState(StockStateBase):
    def to_numpy(self):
        """
        ndarrayに変更する．最後に利用するのがいい？
        """
        cash_unit_mean_array = np.array([self.cash, self.unit_number, self.mean_cost_price])
        return np.concatenate([cash_unit_mean_array, self.price_array.copy()], axis=0)  # コピーすることに注意
    
    @classmethod
    def from_numpy(cls, stock_state_array):
        """
        ndarrayからこのクラスを作成する．基本的に使わない．
        """
        cash = stock_state_array[0]
        unit_number = stock_state_array[1]
        mean_cost_price = stock_state_array[2]
        price_array = stock_state_array[3:]
        
        return cls(cash=cash, unit_number=unit_number, mean_cost_price=mean_cost_price, price_array=price_array)

    def copy(self):
        """
        deepcopyでもいいが，一応明示しておく
        """
        new_state = StockState(cash=self.cash,
                               unit_number=self.unit_number,
                               mean_cost_price=self.mean_cost_price,
                               price_array=self.price_array.copy())
        return new_state
    
    @property
    def now_price(self):
        return self.price_array[0]

# %% [markdown]
# #### 前処理用のクラス

# %% [markdown]
# Stateを変換するためのクラス．

# %%
class NormalizeState():
    def __init__(self, cash_const=1, unit_const=1, price_const=1):
        self.cash_devide_const = cash_const
        self.unit_devide_const = unit_const
        self.price_devide_const = price_const
        
    def __call__(self, state):
        # cash
        cash = state.cash / self.cash_devide_const
        # unit_number
        unit_number = state.unit_number / self.unit_devide_const
        # price_array
        mean_cost_price = state.mean_cost_price / self.price_devide_const
        price_array = state.price_array / self.price_devide_const
            
        new_state = state._replace(cash=cash, unit_number=unit_number, mean_cost_price=mean_cost_price, price_array=price_array)  # 新しいオブジェクト 
        
        return new_state

class NormalizeReward():
    def __init__(self, reward_const=1):
        self.reward_devide_const = reward_const
        
    def __call__(self, reward):
        reward = reward / self.reward_devide_const
        
        return reward

# %% [markdown]
# #### サンプリングのためのクラス

# %%
class WindowSampler():
    def __init__(self, stock_names, start_datetime, end_datetime, freq_str, end_include=False):
        """
        指定した範囲から，エピソード分利用可能なdatetimeをサンプリングするためのクラス
        """
        if isinstance(stock_names, str):  # 銘柄コードが一つの場合
            stock_names = [stock_names]
        self.stock_names = stock_names
        
        self.start_datetime = start_datetime
        self.end_datetime = end_datetime
        # タイムゾーンが同じかチェック
        if self.start_datetime.tzinfo != self.end_datetime.tzinfo:
            raise Exception("The timezone of start_datetime and end_datetime must be same")
        
        self.freq_str = middle_sample_type_with_check(freq_str)
                
        stock_name_datetime_array_list = []
        
        for stock_name in stock_names:
            # 指定した範囲内，周期のdatetimeのndarrayを取得
            if end_include:
                datetime_index = pd.date_range(start=self.start_datetime,
                                               end=self.end_datetime,
                                               freq=self.freq_str
                                              )
                
            else:
                datetime_index = pd.date_range(start=self.start_datetime,
                                               end=get_previous_datetime(self.end_datetime, freq_str=self.freq_str),
                                               freq=self.freq_str
                                              )

            datetime_index = extract_workdays_intraday_jp_index(datetime_index, return_as="index")
            
            stock_name_array = np.full(len(datetime_index), stock_name).astype(object)  # object同士でstackするため
            datetime_array = datetime_index.to_pydatetime()
            stock_name_datetime_array = np.stack([stock_name_array, datetime_array], axis=1)  # [銘柄コード, datetime]のndarray
            stock_name_datetime_array_list.append(stock_name_datetime_array)
            
    
        self.all_stockname_datetime_array = np.concatenate(stock_name_datetime_array_list, axis=0)
        
    def sample(self, seed=None, remove=False):
        if seed is not None and remove:
            raise Exception("If use seed, cannot remove")
            
        random_index = RandomState(seed).randint(0, len(self.all_stockname_datetime_array))
        #ランダムに取り出す
        stock_datetime = self.all_stockname_datetime_array[random_index]
        # 取り出したものを削除
        if remove:
            self.all_stockname_datetime_array = np.delete(self.all_stockname_datetime_array,random_index,axis=0)
        return stock_datetime

# %%
#start_datetime = datetime.datetime(2020,11,1,0,0,0)
#end_datetime = datetime.datetime(2020,12,1,0,0,0)
#stock_names = "6502"
stock_names = ["6502","4755"]

window_sampler = WindowSampler(stock_names, start_datetime, end_datetime, freq_str="T", end_include=False)

# %%
window_sampler.sample(seed=133, remove=False)
# Out:
# array(['4755',
#        datetime.datetime(2020, 11, 27, 10, 53, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>)],
#       dtype=object)

# %% [markdown]
# #### 環境クラス本体

# %%
class OneStockEnv(gym.Env):
    """
    一つの銘柄の株式に関する環境
    """
    def __init__(self, 
                 stock_db,
                 stock_names,
                 start_datetime,
                 end_datetime,
                 freq_str,
                 episode_length,
                 state_time_list=[0],
                 use_ohlc="Close",
                 initial_cash=1.e6,  # 100万円
                 initial_unit=50,  # 初期単元数
                 use_view=False,
                 one_unit_stocks=100,
                 max_units_number=10,
                 low_limmit=1.e3,  # 1000円
                 interpolate=True,
                 sample_remove=False,
                 action_restriction = False,
                 stay_penalty_unit_bound=20,
                 stay_penalty_cash_bound=1.e5,
                ):
        """
        stock_db: StockDataBase
            値を読み込むデータベース．1エピソード分のデータをreset事に読み込む
        stock_names: str list
            利用するデータの銘柄，複数指定した場合はreset時にランダムで決定される
        start_datetime: datetime
            利用するデータの始端
        ed_datetime: datetime
            利用するデータの終端
        freq_str: str
            サンプリング周期
        episode_length: int
            1エピソードの状態の個数
        start_time_list: int list
            状態として利用する株価の現在からのインデックスのリスト．最初の値は現在(0)でなければならない
        use_ohlc: str, defalt: "Close"
            サンプリング周期における利用するデータの指定(Open, High, Low, Close)
        initial_cash: int, defalt: 1.e6
            種銭
        use_view: bool
            reset時にviewを使うかどうか．使う場合，若干高速になるがcloseをしなければならない
        one_unit_stocks: int
            単元数．通常は100だが，独自に定義できる
        max_units_number: int, default: 10
            売買時の単元のセット数の上限・下限．
        low_limmmit: int, defalt:1.e3
            資産額の下限値．この値を下回った場合，エピソードを終了する．
        interpolate: bool
            指定した期間内のデータ中にnanがあった場合，あるいはデータが取得できなかった場合に補間をするかどうか
        sample_remove: bool
            reset時に取得するデータで一度利用したデータを取り除くかどうか
        """
        
        # データベース
        self.stock_db = stock_db
        # ビューの作成
        self.use_view = use_view
        if self.use_view:
            self.stock_view = self.stock_db.create_view(stock_names, start_datetime=start_datetime, end_datetime=end_datetime)
        
        # 利用するohlcのいずれか
        if use_ohlc not in {"Open","High","Low","Close"}:
            raise Exception("use_ohlc must be in {'Open','High','Low','Close'}")
        self.use_ohlc = use_ohlc
        
        self.freq_str = middle_sample_type_with_check(freq_str)
        # 全datetimeデータを保持
        all_datetime_index = pd.date_range(start=start_datetime,
                                           end=get_previous_datetime(end_datetime, freq_str=self.freq_str),
                                           freq=self.freq_str,
                                          )
        
        self.all_datetime_index = extract_workdays_intraday_jp_index(all_datetime_index, return_as="index")
            
        self.episode_length = episode_length
        self.initial_cash = initial_cash
        self.initial_unit = initial_unit
        self.low_limmit = low_limmit
        self.interpolate = interpolate
        self.sample_remove = sample_remove
        self.seed_number = None
        self.action_restriction = action_restriction
        self.stay_penalty_unit_bound = stay_penalty_unit_bound
        self.stay_penalty_cash_bound = stay_penalty_cash_bound
        
        self.gein_reward_weight = 0
        self.price_reward_weight = 1
        self.penalty_weight = 1
        
        if state_time_list[0] != 0:
            raise Exception("The first value of state_time_list must be 0")
        
        self.state_time_list = state_time_list
        
        self.max_state_time = max(state_time_list)  # 利用する未来の状態の現在からのタイムステップ数
        last_start_datetime = self.all_datetime_index[-(self.max_state_time + self.episode_length)]  # エピソードの開始時刻の最後

        self.sampler = WindowSampler(stock_names,
                                     start_datetime=start_datetime,
                                     end_datetime=last_start_datetime,
                                     freq_str=self.freq_str,
                                     end_include=True,  # 最後も含む
                                    )
        # 状態空間と行動空間の定義
        
        min_stock_price = 0
        max_stock_price = np.finfo(np.float32).max
        
        min_cash = 0
        max_cash = np.finfo(np.float32).max
        
        min_unit = 0
        max_unit = 1.e6  # # 100万＊単元まで売買できる 
        
        state_max_list = [max_cash, max_unit, max_stock_price]  # 現金，保有単元数，平均取得価格
        state_max_list.extend([max_stock_price]*len(self.state_time_list))  # [現在価格，指定した未来の価格]
        
        state_min_list = [min_cash, min_unit, min_stock_price]  # 現金，保有単元数，平均取得価格
        state_min_list.extend([min_stock_price]*len(self.state_time_list))  # [現在価格，指定した未来の価格]
                
        state_max_array = np.array(state_max_list, dtype=np.float32)
        state_min_array = np.array(state_min_list, dtype=np.float32)
        
        self.one_unit_stocks = one_unit_stocks  # 独自単元．
        self.max_units_number = max_units_number  # 売買する独自単元の最大数 
        self.action_class_number = 2 * self.max_units_number + 1 # 行動数は 2 * self.max_unit_number + 1(ステイ)
        
        self.action_space = spaces.Discrete(self.action_class_number)
        self.observation_space = spaces.Box(state_min_array, state_max_array, dtype=np.float32)
        
        # 行動クラスの定義
        sell_action_array = np.arange(-self.max_units_number, 0, 1)  # 売りクラス マイナス
        stay_action_arrray = np.array([0])  # ステイクラス
        buy_action_array = np.arange(1, self.max_units_number+1, 1)  # 買いクラス　プラス
        
        self.stay_index = len(sell_action_array)  # ステイのインデックス
        self.action_class_array = np.concatenate([sell_action_array, stay_action_arrray, buy_action_array], axis=0)  # 売りクラス，ステイクラス，買いクラスの順番
        
        self.state = None
        self.steps_beyond_done = None  # エラー処理に利用
        

    def reset(self, select_datetime=None, select_stock_name=None):
        """
        環境をリセットする．エピソード開始日時と銘柄名を指定することで，特定の
        select_datetime: datetime.datetime
            エピソードの開始日時
        select_stock_name: str
            銘柄名
        """
        iter_counter = 0
        while True:  # 条件をクリアしたらreturn,それまで繰り返し
            stock_and_datetime = self.sampler.sample(remove=self.sample_remove, seed=self.seed_number)
            
            if select_stock_name is None:  # 銘柄名が与えられなかった場合
                stock_name = stock_and_datetime[0]
            else:
                if select_stock_name in self.sampler.stock_names:  # 銘柄名の列
                    stock_name = select_stock_name
                else:
                    raise Exception("select_stock must be in stock_names of constructor args")
            
            if select_datetime is None:  # 日時が与えられなかった場合
                episode_start_datetime = stock_and_datetime[1]
            else:
                select_datetime_array = np.array([select_datetime])
                if np.in1d(select_datetime_array, self.sampler.all_stockname_datetime_array[:,1]).item():  # datetimeの列
                    episode_start_datetime = select_datetime
                else:
                    raise Exception("select_datetime must be in sample range of datetime")
                
            episode_start_datetime_index = np.where(self.all_datetime_index==episode_start_datetime)[0].item()  # エピソードで利用する開始時刻

            episode_end_datetime_index = episode_start_datetime_index + (self.episode_length-1) + self.max_state_time  # 状態が利用する未来のデータも含める
            episode_end_datetime = self.all_datetime_index[episode_end_datetime_index]  # エピソードで利用する終端時刻(エピソードの終了時刻ではない)

            # 利用するカラム名
            use_column_name = self.use_ohlc+"_"+stock_name
            
            # エピソード分+状態利用分のデータの取得
        
            if self.use_view:
                episode_series = self.stock_db.search_span(stock_names=stock_name, 
                                                           start_datetime=episode_start_datetime,
                                                           end_datetime=episode_end_datetime,
                                                           freq_str=self.freq_str,
                                                           is_end_include=True,  # 最後の値も含める
                                                           to_tokyo=True,  #必ずTrueに
                                                           view=self.stock_view
                                                           ).loc[:,use_column_name]
                
            else:
                episode_series = self.stock_db.search_span(stock_names=stock_name, 
                                                           start_datetime=episode_start_datetime,
                                                           end_datetime=episode_end_datetime,
                                                           freq_str=self.freq_str,
                                                           is_end_include=True,  # 最後の値も含める
                                                           to_tokyo=True,  #必ずTrueに
                                                           ).loc[:,use_column_name]
            
            # 領域を営業日日中に変更
            
            
            self.episode_series = extract_workdays_intraday_jp(episode_series, return_as="df")
            
            
            
            # 領域にnanが入っているか判定
            if self.episode_series.isnull().sum() > 0:
                IsNan = True
            else:
                IsNan = False
            
            
            # すべて取得できたか判定(データが存在しないか判定)
            part_datetime_bool = (episode_start_datetime <= self.all_datetime_index) & (self.all_datetime_index <= episode_end_datetime)  # 最後も含める
            part_datetime_index = self.all_datetime_index[part_datetime_bool].copy()
                       
            if not self.episode_series.index.equals(part_datetime_index):  # 同一判定
                IsCannotGet = True
            else:
                IsCannotGet = False
            
            iter_counter += 1
            
            # nanが入っておらず，全て取得できた場合．あるいは補間する場合，あるいは日時・もしくはstock_nameが与えられた場合
            if ((not IsNan) and (not IsCannotGet)) or self.interpolate or (select_datetime is not None or stock_name is not None):
                break

        # 線形補間
        if (self.interpolate or (select_datetime is not None or select_stock_name is not None)) and (IsNan or IsCannotGet):  # 補間の必要性がある場合

            if IsCannotGet:  # データが存在しない場合
                # part_datetime_indexに含まれて，self.episode_series.indexに含まれないdatetime
                add_datetime_indice = np.setdiff1d(part_datetime_index.to_pydatetime(), self.episode_series.index.to_pydatetime())
                add_series = pd.Series(index=add_datetime_indice,dtype=np.float64)  # nameは指定しなくてもOK, 値はnan
                new_episode_series = pd.concat([self.episode_series, add_series]).sort_index()  # 存在しないデータがnanで補間
                self.episode_series = new_episode_series
            
            # 線形補間
            self.episode_series.interpolate(limit_direction="both",inplace=True)

                
        cash = self.initial_cash  # 現金
        unit_number = self.initial_unit  # 保有単元数

        # 状態で利用する部分を取得
        #state_datetimes = [self.all_datetime_index[episode_start_datetime_index+add_index].to_pydatetime() for add_index in self.state_time_list]  # datetime.datetimeに変更
        state_datetimes = [self.all_datetime_index[episode_start_datetime_index+add_index] for add_index in self.state_time_list]  # pd.Timestampのリスト
        
        state_prices_bool_array = self.episode_series.index.isin(state_datetimes)

        state_prices_series = self.episode_series.loc[state_prices_bool_array].copy()
        state_prices_array = state_prices_series.values
        
        now_price = state_prices_array[0]  # 最初は現在の価格

        mean_cost_price = now_price  # unit数にかかわらず，最初の平均取得価格は現在価格(unit数が0のときも含める)
        
        # 現状態をアトリビュートとして保持
        self.state = StockState(cash=cash,
                                unit_number=unit_number,
                                mean_cost_price=mean_cost_price,
                                price_array=state_prices_array 
                               )
        
        self.all_property = cash + now_price * unit_number * self.one_unit_stocks
        self.now_datetime = episode_start_datetime  # 現時間
        self.info = {"datetime":self.now_datetime,
                     "stock_name":stock_name,
                     "done_active":None,
                     "iter_counter":iter_counter,
                     "all_property":self.all_property,
                     "penalty":0,
                     "gein_reward":0,
                     "price_reward":0,
                     "reward":0,
                    }
        
        self.now_index = episode_start_datetime_index  # 現時間のインデックス
        self.stock_name = stock_name  # 現銘柄コード
        self.step_counter = 1  # ステップ数のカウンタ
        done = False  # ここではもちろんFalse
        
        # エラー処理で利用
        self.steps_beyond_done = None
        
        return self.state.copy(), 0, done, self.info  # 一応stateをコピー
    
    def step(self, action):
        #assert self.action_space.contains(action), "action {} ({}) invalid".format(action, type(action))
        
        state = self.state
        
        cash = state.cash
        unit_number = state.unit_number
        mean_cost_price = state.mean_cost_price
        prices = state.price_array  # 使わない？
        
        # インデックスを更新
        now_index = self.now_index + 1
        now_datetime = self.all_datetime_index[now_index].to_pydatetime()  # infoで利用
        
        state_datetimes = [self.all_datetime_index[now_index+add_index] for add_index in self.state_time_list]  # pd.Timestampのまま
        
        state_prices_bool_array = self.episode_series.index.isin(state_datetimes)

        state_prices_series = self.episode_series.loc[state_prices_bool_array].copy()
        state_prices_array = state_prices_series.values
        
        # 行動の制約条件（現金より多くかえない，保持数より多くは売れない)
        now_price = state_prices_array[0]  # state_priceの最初は必ずnowでなければならない
        cliped_cash = max(0, cash)  # 条件判定はマイナスを除く
        buy_condition_bool = (cliped_cash - now_price * self.action_class_array * self.one_unit_stocks) >= 0  # 買い条件を満たしたブール, キャッシュがマイナスの時，0にする
        buy_condition_true_max_index = buy_condition_bool.sum() - 1  # 条件を満たした最大値のインデックス
        if buy_condition_true_max_index < 0:  # -1になってしまった場合
            buy_condition_true_max_index = 0

        cliped_unit_number = max(0, unit_number)
        sell_condition_bool = (cliped_unit_number + self.action_class_array) > 0  # 売り条件を満たしたブール．unit_numberがマイナスの時，0にする
        sell_condition_true_min_index = (~sell_condition_bool).sum() - 1  # 条件を満たした最小値のインデックス
        if sell_condition_true_min_index < 0:  # -1になってしまった場合
            sell_condition_true_min_index = 0
                
        # 行動の制約を厳密化
        if self.action_restriction:
            if action < self.stay_index:  # 売りの場合
                if action < sell_condition_true_min_index:  # 行動が最小条件より下になった場合
                    action = sell_condition_true_min_index

            elif action > self.stay_index:  # 買いの場合
                if action > buy_condition_true_max_index:  # 行動が最大条件より上になった場合
                    action = buy_condition_true_max_index
                
            # それ以外(ステイ)はそのまま
        
        penalty = 0
        
        # 売買条件ペナルティ
        trading_penalty = self.get_trading_penalty(sell_condition_true_min_index, buy_condition_true_max_index, action)
        penalty += trading_penalty
        
        # ステイペナルティ
        stay_penalty = self.get_stay_penalty(cash, action, unit_number)
        penalty += stay_penalty
        
        # 追加単元数
        add_unit_number = self.action_class_array[action]  # actionはint?
        
        # reward
        gein_reward = self.get_gein_reward(now_price, add_unit_number)  # 株式売買による報酬
        price_reward = self.get_price_reward(now_price, mean_cost_price, add_unit_number)  # 平均取得価格による報酬
        reward = self.gein_reward_weight * gein_reward + self.price_reward_weight * price_reward +  self.penalty_weight * penalty # 重み
        
        # 状態の更新
        new_unit_number = unit_number + add_unit_number
        new_cash = cash + gein_reward  # 手数料はない
        
        # 平均取得価格の計算
        if add_unit_number > 0:  # 買いの場合
            num = cliped_unit_number * mean_cost_price + add_unit_number * now_price
            den = (cliped_unit_number + add_unit_number)
            new_mean_cost_price = num / den
        else:
            new_mean_cost_price = mean_cost_price  # 元のまま

        self.all_property = cash + now_price * unit_number * self.one_unit_stocks  # 全資産
        
        self.state = StockState(cash=new_cash,
                                unit_number=new_unit_number,
                                mean_cost_price=new_mean_cost_price,
                                price_array=state_prices_array
                               )
        
        self.now_datetime = now_datetime
        
        self.info = {"datetime":self.now_datetime, 
                     "stock_name":self.stock_name,
                     "done_action":action,
                     "all_property":self.all_property,
                     "penalty":penalty,
                     "gein_reward":gein_reward,
                     "price_reward":price_reward,
                     "reward":reward,
                    }  # stock_nameを入れる意味ある？
        
        self.now_index = now_index
        self.step_counter += 1
        
        # doneの更新
        done = (self.step_counter >= self.episode_length) or (self.all_property < self.low_limmit)
        
        # エピソードが終了して，resetが呼ばれる前にstepが呼ばれた時のエラー判定
        if done:
            if self.steps_beyond_done is None:
                self.steps_beyond_done = 0  # 0 に初期化
                
            elif self.steps_beyond_done == 0:  # 0の時のみロギング
                logger.warn(
                    "You are calling 'step()' even though this "
                    "environment has already returned done = True. You"
                    "should always call 'reset()' once you receive 'done ="
                    "True' -- any further steps are undefined behavior"
                )
                self.steps_beyond_done += 1
        
        return self.state.copy(), reward, done, self.info  # 一応stateをコピー

    def get_gein_reward(self, now_price, add_unit_number):
        """
        株式の売却による利益を意味する報酬
        """
        gein_reward = now_price * self.one_unit_stocks * (- add_unit_number) # 買いがプラスであるため，マイナスをかける．cashの計算に利用する．
        return gein_reward
    
    def get_price_reward(self, now_price, mean_cost_price, add_unit_number):
        """
        平均取得価格と現在価格とその売買に関係する報酬
        """
        price_reward = (now_price - mean_cost_price) * self.one_unit_stocks * (- add_unit_number)
        return price_reward
    
    def get_trading_penalty(self, sell_condition_index, buy_condition_index, action):
        """
        売買条件を制限するペナルティ．
        """
        penalty = 0
        # 売買条件ペナルティ
        if action < self.stay_index:  # 売りの場合
            if action < sell_condition_index:  # 行動が最小条件より下になった場合
                prepenalty = - (sell_condition_index - action) * self.initial_cash * 0.5
                assert prepenalty <= 0,"this penalty must be minus {}".format(prepenalty)
                penalty += prepenalty
            
        elif action > self.stay_index:  # 買いの場合
            if action > buy_condition_index:  # 行動が最大条件より上になった場合
                prepenalty = - (action - buy_condition_index) * self.initial_cash * 0.5
                assert prepenalty <= 0,"this penalty must be minus {}".format(prepenalty)
                penalty += prepenalty
        return penalty
    
    def get_stay_penalty(self, cash, action, unit_number):
        penalty = 0
        condition_list = []
        low_unit_stay_condition = action == self.stay_index and unit_number < self.stay_penalty_unit_bound  # 行動がステイかつユニット数が閾値以下の場合
        condition_list.append(low_unit_stay_condition)
        low_cash_stay_condition = action == self.stay_index and cash < self.stay_penalty_cash_bound  # 行動がステイかつ現金が閾値以下の場合
        condition_list.append(low_cash_stay_condition)
        
        if any(condition_list):  # 条件のどれかが当てはまる場合
            #prepenalty = cash * (-0.10)  # 現金のx%のペナルティ
            prepenalty = - self.initial_cash * (0.2)
            penalty += prepenalty
        return penalty
    
    def close(self):
        """
        ビューのクローズとseedのリセット
        """
        if self.use_view:
            self.stock_view.close()
        self.seed(None)  # シードの初期化
    
    def seed(self, seed=None):
        """
        reset時のサンプリングのseedを設定する．リセットの場合，何も指定しないかNoneを指定
        """
        self.seed_number = seed
        
    def set_weight(self, gein_reward_weight=0, price_reward_weight=1, penalty_weight=1):
        self.gein_reward_weight = gein_reward_weight
        self.price_reward_weight = price_reward_weight
        self.penalty_weight = penalty_weight

# %%
initial_cash = 1.e6  # 種銭：100万円
initial_unit = 50  # 初期単元数

freq_str = "5T"
episode_length = 12*5*7  # 1週間

#state_time_list = [0,1,12,12*3,12*5,12*5*3],  # [現在，次時刻，一時間後，3時間後，5時間後(1日後), 15時間後(3日後)]
state_time_list = [0,
                   1,
                   2,
                   6,
                   12,
                   12*2,
                   12*3,
                   12*4,
                   12*5*1,
                   12*5*2,
                   12*5*3,
                   12*5*4,
                   12*5*5,
                   ]  # 現在，5分後, 10分後, 30分後, 1時間後, 2時間後, 3時間後, 4時間後, 1日後, 2日後, 3日後, 4日後, 5日後, 6日後, 7日後

one_unit_stocks = 20
max_units_number = 5
stay_penalty_unit_bound=30
stay_penalty_cash_bound = 1.e5


env = OneStockEnv(stock_db,
                  stock_names=stock_names,
                  start_datetime=start_datetime,
                  end_datetime=end_datetime,
                  freq_str="5T",
                  episode_length=episode_length,  # 一週間
                  state_time_list=state_time_list,
                  use_ohlc=use_ohlc,  # 終値を使う
                  initial_cash=initial_cash,  # 種銭
                  initial_unit=initial_unit,
                  use_view=False,
                  one_unit_stocks=one_unit_stocks,  # 独自単元株数
                  max_units_number=max_units_number,  # 一度に売買できる独自単元数
                  low_limmit=1.e4,  # 全財産がこの値以下になれば終了
                  interpolate=True,
                  stay_penalty_unit_bound=stay_penalty_unit_bound,  # このunit数以下の場合のstayはペナルティ
                  stay_penalty_cash_bound=stay_penalty_cash_bound,  # このcash以下の場合のstayはペナルティ
                 )

# %%
#env.reset(select_datetime=jst_timezone.localize(datetime.datetime(2020, 11, 4, 14, 0)), select_stock_name="4755")
env.reset()
# Out:
# (StockState(cash=1000000.0, unit_number=50, mean_cost_price=1012.0, price_array=array([1012., 1012., 1009., 1016., 1022., 1018., 1016., 1018., 1047.,
#         1042., 1082., 1100., 1062.])),
#  0,
#  False,
#  {'datetime': datetime.datetime(2020, 11, 2, 9, 15, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>),
#   'stock_name': '4755',
#   'done_active': None,
#   'iter_counter': 1,
#   'all_property': 2012000.0,
#   'penalty': 0,
#   'gein_reward': 0,
#   'price_reward': 0,
#   'reward': 0})

# %% [markdown]
# ### 環境の動きをデバッグ

# %%
state_list = []
info_list = []

for i in range(episode_length-1):
    action = env.action_space.sample()
    #action = 15
    observe, reward, done, info = env.step(action)

    cash = observe.cash
    unit_number = observe.unit_number
    now_price = observe.now_price

    done_action = info["done_action"]
    def print_states():
        print("action selected:{}, done:{}".format(action, done_action))
        print("done_buy_sell stocks:{}, deal:{}:".format(env.action_class_array[done_action]*env.one_unit_stocks, -now_price*env.action_class_array[done_action]))
        print("observe:",observe)
        print("cash:",cash)
        print("stocks:",unit_number*env.one_unit_stocks)
        print("all property:",env.all_property)
        print("penalty:",info["penalty"])
        print("gein_reward:",info["gein_reward"])
        print("price_reward:",info["price_reward"])
        print("#################################")
    
    #print_states()
    state_list.append(observe)
    info_list.append(info)

# %% [markdown]
# #### 環境のデバッグ用グラフ

# %%
plot_trading_process_bokeh(state_list, info_list, env, is_save=False)
# Out:
#   <div class="bk-root" id="d9bf19a3-68cc-406e-9d09-566db8c11714" data-root-id="1456"></div>

# %%
price_reward_array = np.array(list(map(lambda info: info["price_reward"], info_list)))
gein_reward_array = np.array(list(map(lambda info: info["gein_reward"], info_list)))



abs_price_reward_array = np.abs(price_reward_array)
print(abs_price_reward_array.mean())

abs_gein_reward_array = np.abs(gein_reward_array)
print(abs_gein_reward_array.mean())
# Out:
# 178.65371594742118
# 59858.42482100239

# %% [markdown]
# ### rewardの重み

# %%
gein_price_ratio = abs_price_reward_array.mean() / abs_gein_reward_array.mean()

#env.set_weight(gein_reward_weight=gein_price_ratio*0.2, price_reward_weight=1*0.8, penalty_weight=1)
env.set_weight(gein_reward_weight=0, price_reward_weight=1, penalty_weight=1)

# %%
state_transform = NormalizeState(cash_const=initial_cash,
                                 unit_const=100,
                                 price_const=1.e4,
                                )

reward_transform = NormalizeReward(reward_const=5.e3,
                                  )

# %%
print("observe:",observe)
print("reward:",reward)

print("normalized observe:",state_transform(observe))
print("normalized reward:",reward_transform(reward))
# Out:
# observe: StockState(cash=4750960.0, unit_number=-130, mean_cost_price=1123.0, price_array=array([1125., 1122., 1123., 1128., 1134., 1129., 1128., 1131., 1086.,
#        1105., 1124., 1110., 1091.]))
# reward: -200000.0
# normalized observe: StockState(cash=4.75096, unit_number=-1.3, mean_cost_price=0.1123, price_array=array([0.1125, 0.1122, 0.1123, 0.1128, 0.1134, 0.1129, 0.1128, 0.1131,
#        0.1086, 0.1105, 0.1124, 0.111 , 0.1091]))
# normalized reward: -40.0

# %% [markdown]
# ### Q関数の定義

# %%
class QFunction(nn.Module):
    def __init__(self, obs_size, n_actions):
        super().__init__()
        self.fc1 = nn.Linear(obs_size, 32)
        self.bn1 = nn.BatchNorm1d(32)
        
        self.fc2 = nn.Linear(32, 128)
        self.bn2 = nn.BatchNorm1d(128)
        
        self.fc3 = nn.Linear(128, 256)
        self.bn3 = nn.BatchNorm1d(256)
        
        self.fc4 = nn.Linear(256, n_actions)
    def forward(self, x):
        x = F.relu(self.bn1(self.fc1(x)))
        x = F.relu(self.bn2(self.fc2(x)))
        x = F.relu(self.bn3(self.fc3(x)))
        
        x = self.fc4(x)
        out = pfrl.action_value.DiscreteActionValue(x)
        return out

# %% [markdown]
# ### Q関数の初期化

# %%
obs_size = env.observation_space.low.size
print("observation size:", obs_size)
n_actions = env.action_space.n
print("action size:",n_actions)
q_func = QFunction(obs_size, n_actions)
# Out:
# observation size: 16
# action size: 11

# %% [markdown]
# ### エージェントの定義

# %% [markdown]
# 今回はDobuleQ

# %%
optimizer = torch.optim.Adam(q_func.parameters(), eps=1e-3)

gamma = 0.95

init_episilon = 0.3
init_explorer = pfrl.explorers.ConstantEpsilonGreedy(epsilon=init_episilon,
                                                random_action_func=env.action_space.sample
                                               )

replay_buffer = pfrl.replay_buffers.ReplayBuffer(capacity=10**6)

phi = lambda x: x.astype(np.float32, copy=False)

gpu = -1 # -1 is cpu

agent = pfrl.agents.DoubleDQN(
    q_function=q_func,
    optimizer=optimizer,
    replay_buffer=replay_buffer,
    gamma=gamma,
    explorer=init_explorer,
    replay_start_size=500,
    update_interval=1,
    target_update_interval=100,
    phi=phi,
    gpu=gpu
)

# %% [markdown]
# ###  イプシロンの減衰

# %%
def extinction_epsilon(episode_number):
    if episode_number < 200:
        return 0.9
    elif episode_number < 400:
        return 0.8
    elif episode_number < 600:
        return 0.7
    elif episode_number < 800:
        return 0.6
    elif episode_number < 1000:
        return 0.5
    elif episode_number < 1200:
        return 0.4
    elif episode_number < 1400:
        return 0.3
    elif episode_number < 1600:
        return 0.2
    else:
        return 0.1

# %% [markdown]
# ### プロファイリング

# %%
def episode():
    with agent.eval_mode():
        obs,_,_,_ = env.reset()

        normalized_obs = state_transform(obs)
        #normalized_obs = obs
        print(normalized_obs)
        R = 0
        t = 0

        while True:
            action = agent.act(normalized_obs.to_numpy())
            obs, reward, done, info = env.step(action)

            R += reward
            t += 1
            reset = False  # リセットタイミングはdoneに依存
            # state, rewardの前処理
            normalized_obs = state_transform(obs)
            #normalized_reward = reward_transform(reward)
            #normalized_obs = obs
            normalized_reward = reward
            agent.observe(normalized_obs.to_numpy(), normalized_reward, done, reset)
            
            print("\r t={}".format(t),end="")

            if done:
                break
        print("\n")

# %% [markdown]
# #### 速度のプロファイリング

# %%
from line_profiler import LineProfiler
prf = LineProfiler()                                                                                         
prf.add_module(StockState)
prf.add_module(OneStockEnv)
#prf.add_function()                                                                                      
prf.runcall(episode)                                                                                          
prf.print_stats()
# Out:
# StockState(cash=1.0, unit_number=0.5, mean_cost_price=0.1046, price_array=array([0.1046, 0.1044, 0.1045, 0.1044, 0.1048, 0.1042, 0.104 , 0.1046,
#        0.1035, 0.1081, 0.1112, 0.1111, 0.1097]))
#  t=419
#
# Timer unit: 1e-07 s
#
# Total time: 0.0637423 s
# File: <ipython-input-16-3e192410123e>
# Function: to_numpy at line 5
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      5                                               def to_numpy(self):
#      6                                                   """
#      7                                                   ndarrayに変更する．最後に利用するのがいい？
#      8                                                   """
#      9       838     287774.0    343.4     45.1          cash_unit_mean_array = np.array([self.cash, self.unit_number, self.mean_cost_price])
#     10       838     349649.0    417.2     54.9          return np.concatenate([cash_unit_mean_array, self.price_array.copy()], axis=0)  # コピーすることに注意
#
# Total time: 0.017734 s
# File: <ipython-input-16-3e192410123e>
# Function: copy at line 24
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     24                                               def copy(self):
#     25                                                   """
#     26                                                   deepcopyでもいいが，一応明示しておく
#     27                                                   """
#     28       420      37587.0     89.5     21.2          new_state = StockState(cash=self.cash,
#     29       420      17603.0     41.9      9.9                                 unit_number=self.unit_number,
#     30       420      13257.0     31.6      7.5                                 mean_cost_price=self.mean_cost_price,
#     31       420      98709.0    235.0     55.7                                 price_array=self.price_array.copy())
#     32       420      10184.0     24.2      5.7          return new_state
#
# Total time: 0 s
# File: <ipython-input-21-95c3085e6d70>
# Function: __init__ at line 5
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      5                                               def __init__(self,
#      6                                                            stock_db,
#      7                                                            stock_names,
#      8                                                            start_datetime,
#      9                                                            end_datetime,
#     10                                                            freq_str,
#     11                                                            episode_length,
#     12                                                            state_time_list=[0],
#     13                                                            use_ohlc="Close",
#     14                                                            initial_cash=1.e6,  # 100万円
#     15                                                            initial_unit=50,  # 初期単元数
#     16                                                            use_view=False,
#     17                                                            one_unit_stocks=100,
#     18                                                            max_units_number=10,
#     19                                                            low_limmit=1.e3,  # 1000円
#     20                                                            interpolate=True,
#     21                                                            sample_remove=False,
#     22                                                            action_restriction = False,
#     23                                                            stay_penalty_unit_bound=20,
#     24                                                            stay_penalty_cash_bound=1.e5,
#     25                                                           ):
#     26                                                   """
#     27                                                   stock_db: StockDataBase
#     28                                                       値を読み込むデータベース．1エピソード分のデータをreset事に読み込む
#     29                                                   stock_names: str list
#     30                                                       利用するデータの銘柄，複数指定した場合はreset時にランダムで決定される
#     31                                                   start_datetime: datetime
#     32                                                       利用するデータの始端
#     33                                                   ed_datetime: datetime
#     34                                                       利用するデータの終端
#     35                                                   freq_str: str
#     36                                                       サンプリング周期
#     37                                                   episode_length: int
#     38                                                       1エピソードの状態の個数
#     39                                                   start_time_list: int list
#     40                                                       状態として利用する株価の現在からのインデックスのリスト．最初の値は現在(0)でなければならない
#     41                                                   use_ohlc: str, defalt: "Close"
#     42                                                       サンプリング周期における利用するデータの指定(Open, High, Low, Close)
#     43                                                   initial_cash: int, defalt: 1.e6
#     44                                                       種銭
#     45                                                   use_view: bool
#     46                                                       reset時にviewを使うかどうか．使う場合，若干高速になるがcloseをしなければならない
#     47                                                   one_unit_stocks: int
#     48                                                       単元数．通常は100だが，独自に定義できる
#     49                                                   max_units_number: int, default: 10
#     50                                                       売買時の単元のセット数の上限・下限．
#     51                                                   low_limmmit: int, defalt:1.e3
#     52                                                       資産額の下限値．この値を下回った場合，エピソードを終了する．
#     53                                                   interpolate: bool
#     54                                                       指定した期間内のデータ中にnanがあった場合，あるいはデータが取得できなかった場合に補間をするかどうか
#     55                                                   sample_remove: bool
#     56                                                       reset時に取得するデータで一度利用したデータを取り除くかどうか
#     57                                                   """
#     58
#     59                                                   # データベース
#     60                                                   self.stock_db = stock_db
#     61                                                   # ビューの作成
#     62                                                   self.use_view = use_view
#     63                                                   if self.use_view:
#     64                                                       self.stock_view = self.stock_db.create_view(stock_names, start_datetime=start_datetime, end_datetime=end_datetime)
#     65
#     66                                                   # 利用するohlcのいずれか
#     67                                                   if use_ohlc not in {"Open","High","Low","Close"}:
#     68                                                       raise Exception("use_ohlc must be in {'Open','High','Low','Close'}")
#     69                                                   self.use_ohlc = use_ohlc
#     70
#     71                                                   self.freq_str = middle_sample_type_with_check(freq_str)
#     72                                                   # 全datetimeデータを保持
#     73                                                   all_datetime_index = pd.date_range(start=start_datetime,
#     74                                                                                      end=get_previous_datetime(end_datetime, freq_str=self.freq_str),
#     75                                                                                      freq=self.freq_str,
#     76                                                                                     )
#     77
#     78                                                   self.all_datetime_index = extract_workdays_intraday_jp_index(all_datetime_index, return_as="index")
#     79
#     80                                                   self.episode_length = episode_length
#     81                                                   self.initial_cash = initial_cash
#     82                                                   self.initial_unit = initial_unit
#     83                                                   self.low_limmit = low_limmit
#     84                                                   self.interpolate = interpolate
#     85                                                   self.sample_remove = sample_remove
#     86                                                   self.seed_number = None
#     87                                                   self.action_restriction = action_restriction
#     88                                                   self.stay_penalty_unit_bound = stay_penalty_unit_bound
#     89                                                   self.stay_penalty_cash_bound = stay_penalty_cash_bound
#     90
#     91                                                   self.gein_reward_weight = 0
#     92                                                   self.price_reward_weight = 1
#     93                                                   self.penalty_weight = 1
#     94
#     95                                                   if state_time_list[0] != 0:
#     96                                                       raise Exception("The first value of state_time_list must be 0")
#     97
#     98                                                   self.state_time_list = state_time_list
#     99
#    100                                                   self.max_state_time = max(state_time_list)  # 利用する未来の状態の現在からのタイムステップ数
#    101                                                   last_start_datetime = self.all_datetime_index[-(self.max_state_time + self.episode_length)]  # エピソードの開始時刻の最後
#    102
#    103                                                   self.sampler = WindowSampler(stock_names,
#    104                                                                                start_datetime=start_datetime,
#    105                                                                                end_datetime=last_start_datetime,
#    106                                                                                freq_str=self.freq_str,
#    107                                                                                end_include=True,  # 最後も含む
#    108                                                                               )
#    109                                                   # 状態空間と行動空間の定義
#    110
#    111                                                   min_stock_price = 0
#    112                                                   max_stock_price = np.finfo(np.float32).max
#    113
#    114                                                   min_cash = 0
#    115                                                   max_cash = np.finfo(np.float32).max
#    116
#    117                                                   min_unit = 0
#    118                                                   max_unit = 1.e6  # # 100万＊単元まで売買できる
#    119
#    120                                                   state_max_list = [max_cash, max_unit, max_stock_price]  # 現金，保有単元数，平均取得価格
#    121                                                   state_max_list.extend([max_stock_price]*len(self.state_time_list))  # [現在価格，指定した未来の価格]
#    122
#    123                                                   state_min_list = [min_cash, min_unit, min_stock_price]  # 現金，保有単元数，平均取得価格
#    124                                                   state_min_list.extend([min_stock_price]*len(self.state_time_list))  # [現在価格，指定した未来の価格]
#    125
#    126                                                   state_max_array = np.array(state_max_list, dtype=np.float32)
#    127                                                   state_min_array = np.array(state_min_list, dtype=np.float32)
#    128
#    129                                                   self.one_unit_stocks = one_unit_stocks  # 独自単元．
#    130                                                   self.max_units_number = max_units_number  # 売買する独自単元の最大数
#    131                                                   self.action_class_number = 2 * self.max_units_number + 1 # 行動数は 2 * self.max_unit_number + 1(ステイ)
#    132
#    133                                                   self.action_space = spaces.Discrete(self.action_class_number)
#    134                                                   self.observation_space = spaces.Box(state_min_array, state_max_array, dtype=np.float32)
#    135
#    136                                                   # 行動クラスの定義
#    137                                                   sell_action_array = np.arange(-self.max_units_number, 0, 1)  # 売りクラス マイナス
#    138                                                   stay_action_arrray = np.array([0])  # ステイクラス
#    139                                                   buy_action_array = np.arange(1, self.max_units_number+1, 1)  # 買いクラス　プラス
#    140
#    141                                                   self.stay_index = len(sell_action_array)  # ステイのインデックス
#    142                                                   self.action_class_array = np.concatenate([sell_action_array, stay_action_arrray, buy_action_array], axis=0)  # 売りクラス，ステイクラス，買いクラスの順番
#    143
#    144                                                   self.state = None
#    145                                                   self.steps_beyond_done = None  # エラー処理に利用
#
# Total time: 4.84568 s
# File: <ipython-input-21-95c3085e6d70>
# Function: reset at line 148
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    148                                               def reset(self, select_datetime=None, select_stock_name=None):
#    149                                                   """
#    150                                                   環境をリセットする．エピソード開始日時と銘柄名を指定することで，特定の
#    151                                                   select_datetime: datetime.datetime
#    152                                                       エピソードの開始日時
#    153                                                   select_stock_name: str
#    154                                                       銘柄名
#    155                                                   """
#    156         1        437.0    437.0      0.0          iter_counter = 0
#    157         1        139.0    139.0      0.0          while True:  # 条件をクリアしたらreturn,それまで繰り返し
#    158         1      32478.0  32478.0      0.1              stock_and_datetime = self.sampler.sample(remove=self.sample_remove, seed=self.seed_number)
#    159
#    160         1        153.0    153.0      0.0              if select_stock_name is None:  # 銘柄名が与えられなかった場合
#    161         1        180.0    180.0      0.0                  stock_name = stock_and_datetime[0]
#    162                                                       else:
#    163                                                           if select_stock_name in self.sampler.stock_names:  # 銘柄名の列
#    164                                                               stock_name = select_stock_name
#    165                                                           else:
#    166                                                               raise Exception("select_stock must be in stock_names of constructor args")
#    167
#    168         1        119.0    119.0      0.0              if select_datetime is None:  # 日時が与えられなかった場合
#    169         1        142.0    142.0      0.0                  episode_start_datetime = stock_and_datetime[1]
#    170                                                       else:
#    171                                                           select_datetime_array = np.array([select_datetime])
#    172                                                           if np.in1d(select_datetime_array, self.sampler.all_stockname_datetime_array[:,1]).item():  # datetimeの列
#    173                                                               episode_start_datetime = select_datetime
#    174                                                           else:
#    175                                                               raise Exception("select_datetime must be in sample range of datetime")
#    176
#    177         1      18584.0  18584.0      0.0              episode_start_datetime_index = np.where(self.all_datetime_index==episode_start_datetime)[0].item()  # エピソードで利用する開始時刻
#    178
#    179         1        223.0    223.0      0.0              episode_end_datetime_index = episode_start_datetime_index + (self.episode_length-1) + self.max_state_time  # 状態が利用する未来のデータも含める
#    180         1       8768.0   8768.0      0.0              episode_end_datetime = self.all_datetime_index[episode_end_datetime_index]  # エピソードで利用する終端時刻(エピソードの終了時刻ではない)
#    181
#    182                                                       # 利用するカラム名
#    183         1        173.0    173.0      0.0              use_column_name = self.use_ohlc+"_"+stock_name
#    184
#    185                                                       # エピソード分+状態利用分のデータの取得
#    186
#    187         1        121.0    121.0      0.0              if self.use_view:
#    188                                                           episode_series = self.stock_db.search_span(stock_names=stock_name,
#    189                                                                                                      start_datetime=episode_start_datetime,
#    190                                                                                                      end_datetime=episode_end_datetime,
#    191                                                                                                      freq_str=self.freq_str,
#    192                                                                                                      is_end_include=True,  # 最後の値も含める
#    193                                                                                                      to_tokyo=True,  #必ずTrueに
#    194                                                                                                      view=self.stock_view
#    195                                                                                                      ).loc[:,use_column_name]
#    196
#    197                                                       else:
#    198         1        149.0    149.0      0.0                  episode_series = self.stock_db.search_span(stock_names=stock_name,
#    199         1        119.0    119.0      0.0                                                             start_datetime=episode_start_datetime,
#    200         1        119.0    119.0      0.0                                                             end_datetime=episode_end_datetime,
#    201         1        129.0    129.0      0.0                                                             freq_str=self.freq_str,
#    202         1        117.0    117.0      0.0                                                             is_end_include=True,  # 最後の値も含める
#    203         1   47940471.0 47940471.0     98.9                                                             to_tokyo=True,  #必ずTrueに
#    204         1      14656.0  14656.0      0.0                                                             ).loc[:,use_column_name]
#    205
#    206                                                       # 領域を営業日日中に変更
#    207
#    208
#    209         1     241715.0 241715.0      0.5              self.episode_series = extract_workdays_intraday_jp(episode_series, return_as="df")
#    210
#    211
#    212
#    213                                                       # 領域にnanが入っているか判定
#    214         1      19880.0  19880.0      0.0              if self.episode_series.isnull().sum() > 0:
#    215         1        164.0    164.0      0.0                  IsNan = True
#    216                                                       else:
#    217                                                           IsNan = False
#    218
#    219
#    220                                                       # すべて取得できたか判定(データが存在しないか判定)
#    221         1      10695.0  10695.0      0.0              part_datetime_bool = (episode_start_datetime <= self.all_datetime_index) & (self.all_datetime_index <= episode_end_datetime)  # 最後も含める
#    222         1      11934.0  11934.0      0.0              part_datetime_index = self.all_datetime_index[part_datetime_bool].copy()
#    223
#    224         1       2035.0   2035.0      0.0              if not self.episode_series.index.equals(part_datetime_index):  # 同一判定
#    225                                                           IsCannotGet = True
#    226                                                       else:
#    227         1         63.0     63.0      0.0                  IsCannotGet = False
#    228
#    229         1         67.0     67.0      0.0              iter_counter += 1
#    230
#    231                                                       # nanが入っておらず，全て取得できた場合．あるいは補間する場合，あるいは日時・もしくはstock_nameが与えられた場合
#    232         1         89.0     89.0      0.0              if ((not IsNan) and (not IsCannotGet)) or self.interpolate or (select_datetime is not None or stock_name is not None):
#    233         1         58.0     58.0      0.0                  break
#    234
#    235                                                   # 線形補間
#    236         1         61.0     61.0      0.0          if (self.interpolate or (select_datetime is not None or select_stock_name is not None)) and (IsNan or IsCannotGet):  # 補間の必要性がある場合
#    237
#    238         1         55.0     55.0      0.0              if IsCannotGet:  # データが存在しない場合
#    239                                                           # part_datetime_indexに含まれて，self.episode_series.indexに含まれないdatetime
#    240                                                           add_datetime_indice = np.setdiff1d(part_datetime_index.to_pydatetime(), self.episode_series.index.to_pydatetime())
#    241                                                           add_series = pd.Series(index=add_datetime_indice,dtype=np.float64)  # nameは指定しなくてもOK, 値はnan
#    242                                                           new_episode_series = pd.concat([self.episode_series, add_series]).sort_index()  # 存在しないデータがnanで補間
#    243                                                           self.episode_series = new_episode_series
#    244
#    245                                                       # 線形補間
#    246         1      68529.0  68529.0      0.1              self.episode_series.interpolate(limit_direction="both",inplace=True)
#    247
#    248
#    249         1        149.0    149.0      0.0          cash = self.initial_cash  # 現金
#    250         1         72.0     72.0      0.0          unit_number = self.initial_unit  # 保有単元数
#    251
#    252                                                   # 状態で利用する部分を取得
#    253                                                   #state_datetimes = [self.all_datetime_index[episode_start_datetime_index+add_index].to_pydatetime() for add_index in self.state_time_list]  # datetime.datetimeに変更
#    254         1      17258.0  17258.0      0.0          state_datetimes = [self.all_datetime_index[episode_start_datetime_index+add_index] for add_index in self.state_time_list]  # pd.Timestampのリスト
#    255
#    256         1      28068.0  28068.0      0.1          state_prices_bool_array = self.episode_series.index.isin(state_datetimes)
#    257
#    258         1      32753.0  32753.0      0.1          state_prices_series = self.episode_series.loc[state_prices_bool_array].copy()
#    259         1        457.0    457.0      0.0          state_prices_array = state_prices_series.values
#    260
#    261         1        214.0    214.0      0.0          now_price = state_prices_array[0]  # 最初は現在の価格
#    262
#    263         1        154.0    154.0      0.0          mean_cost_price = now_price  # unit数にかかわらず，最初の平均取得価格は現在価格(unit数が0のときも含める)
#    264
#    265                                                   # 現状態をアトリビュートとして保持
#    266         1        180.0    180.0      0.0          self.state = StockState(cash=cash,
#    267         1        152.0    152.0      0.0                                  unit_number=unit_number,
#    268         1        150.0    150.0      0.0                                  mean_cost_price=mean_cost_price,
#    269         1        448.0    448.0      0.0                                  price_array=state_prices_array
#    270                                                                          )
#    271
#    272         1        432.0    432.0      0.0          self.all_property = cash + now_price * unit_number * self.one_unit_stocks
#    273         1        284.0    284.0      0.0          self.now_datetime = episode_start_datetime  # 現時間
#    274         1        168.0    168.0      0.0          self.info = {"datetime":self.now_datetime,
#    275         1        158.0    158.0      0.0                       "stock_name":stock_name,
#    276         1        152.0    152.0      0.0                       "done_active":None,
#    277         1        154.0    154.0      0.0                       "iter_counter":iter_counter,
#    278         1        159.0    159.0      0.0                       "all_property":self.all_property,
#    279         1        154.0    154.0      0.0                       "penalty":0,
#    280         1        150.0    150.0      0.0                       "gein_reward":0,
#    281         1        154.0    154.0      0.0                       "price_reward":0,
#    282         1        228.0    228.0      0.0                       "reward":0,
#    283                                                               }
#    284
#    285         1        176.0    176.0      0.0          self.now_index = episode_start_datetime_index  # 現時間のインデックス
#    286         1        165.0    165.0      0.0          self.stock_name = stock_name  # 現銘柄コード
#    287         1        176.0    176.0      0.0          self.step_counter = 1  # ステップ数のカウンタ
#    288         1        156.0    156.0      0.0          done = False  # ここではもちろんFalse
#    289
#    290                                                   # エラー処理で利用
#    291         1        168.0    168.0      0.0          self.steps_beyond_done = None
#    292
#    293         1       1085.0   1085.0      0.0          return self.state.copy(), 0, done, self.info  # 一応stateをコピー
#
# Total time: 3.49615 s
# File: <ipython-input-21-95c3085e6d70>
# Function: step at line 295
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    295                                               def step(self, action):
#    296                                                   #assert self.action_space.contains(action), "action {} ({}) invalid".format(action, type(action))
#    297
#    298       419      50421.0    120.3      0.1          state = self.state
#    299
#    300       419      46981.0    112.1      0.1          cash = state.cash
#    301       419      33375.0     79.7      0.1          unit_number = state.unit_number
#    302       419      47100.0    112.4      0.1          mean_cost_price = state.mean_cost_price
#    303       419      30647.0     73.1      0.1          prices = state.price_array  # 使わない？
#    304
#    305                                                   # インデックスを更新
#    306       419      37745.0     90.1      0.1          now_index = self.now_index + 1
#    307       419    1403082.0   3348.6      4.0          now_datetime = self.all_datetime_index[now_index].to_pydatetime()  # infoで利用
#    308
#    309       419    9145529.0  21827.0     26.2          state_datetimes = [self.all_datetime_index[now_index+add_index] for add_index in self.state_time_list]  # pd.Timestampのまま
#    310
#    311       419   10590460.0  25275.6     30.3          state_prices_bool_array = self.episode_series.index.isin(state_datetimes)
#    312
#    313       419    9552448.0  22798.2     27.3          state_prices_series = self.episode_series.loc[state_prices_bool_array].copy()
#    314       419     115217.0    275.0      0.3          state_prices_array = state_prices_series.values
#    315
#    316                                                   # 行動の制約（現金より多くかえない，保持数より多くは売れない)
#    317       419      52012.0    124.1      0.1          now_price = state_prices_array[0]  # state_priceの最初は必ずnowでなければならない
#    318       419      96418.0    230.1      0.3          cliped_cash = max(0, cash)  # 条件判定はマイナスを除く
#    319       419     520438.0   1242.1      1.5          buy_condition_bool = (cliped_cash - now_price * self.action_class_array * self.one_unit_stocks) >= 0  # 買い条件を満たしたブール, キャッシュがマイナスの時，0にする
#    320       419     282729.0    674.8      0.8          buy_condition_true_max_index = buy_condition_bool.sum() - 1  # 条件を満たした最大値のインデックス
#    321       419      40791.0     97.4      0.1          if buy_condition_true_max_index < 0:  # -1になってしまった場合
#    322                                                       buy_condition_true_max_index = 0
#    323
#    324       419      59722.0    142.5      0.2          cliped_unit_number = max(0, unit_number)
#    325       419     146793.0    350.3      0.4          sell_condition_bool = (cliped_unit_number + self.action_class_array) > 0  # 売り条件を満たしたブール．unit_numberがマイナスの時，0にする
#    326       419     237802.0    567.5      0.7          sell_condition_true_min_index = (~sell_condition_bool).sum() - 1  # 条件を満たした最小値のインデックス
#    327       419      43881.0    104.7      0.1          if sell_condition_true_min_index < 0:  # -1になってしまった場合
#    328        23       3890.0    169.1      0.0              sell_condition_true_min_index = 0
#    329
#    330                                                   # 行動の制約を厳密化
#    331       419      29869.0     71.3      0.1          if self.action_restriction:
#    332                                                       if action < self.stay_index:  # 売りの場合
#    333                                                           if action < sell_condition_true_min_index:  # 行動が最小条件より下になった場合
#    334                                                               action = sell_condition_true_min_index
#    335
#    336                                                       elif action > self.stay_index:  # 買いの場合
#    337                                                           if action > buy_condition_true_max_index:  # 行動が最大条件より上になった場合
#    338                                                               action = buy_condition_true_max_index
#    339
#    340                                                       # それ以外(ステイ)はそのまま
#    341
#    342       419      25879.0     61.8      0.1          penalty = 0
#    343
#    344                                                   # 売買条件ペナルティ
#    345       419     392903.0    937.7      1.1          trading_penalty = self.get_trading_penalty(sell_condition_true_min_index, buy_condition_true_max_index, action)
#    346       419      32038.0     76.5      0.1          penalty += trading_penalty
#    347
#    348                                                   # ステイペナルティ
#    349       419     331910.0    792.1      0.9          stay_penalty = self.get_stay_penalty(cash, action, unit_number)
#    350       419      46319.0    110.5      0.1          penalty += stay_penalty
#    351
#    352                                                   # 追加単元数
#    353       419      48768.0    116.4      0.1          add_unit_number = self.action_class_array[action]  # actionはint?
#    354
#    355                                                   # reward
#    356       419     130259.0    310.9      0.4          gein_reward = self.get_gein_reward(now_price, add_unit_number)  # 株式売買による報酬
#    357       419     122787.0    293.0      0.4          price_reward = self.get_price_reward(now_price, mean_cost_price, add_unit_number)  # 平均取得価格による報酬
#    358       419      78088.0    186.4      0.2          reward = self.gein_reward_weight * gein_reward + self.price_reward_weight * price_reward +  self.penalty_weight * penalty # 重み
#    359
#    360                                                   # 状態の更新
#    361       419      31917.0     76.2      0.1          new_unit_number = unit_number + add_unit_number
#    362       419      29853.0     71.2      0.1          new_cash = cash + gein_reward  # 手数料はない
#    363
#    364                                                   # 平均取得価格の計算
#    365       419      38381.0     91.6      0.1          if add_unit_number > 0:  # 買いの場合
#    366       144      52475.0    364.4      0.2              num = cliped_unit_number * mean_cost_price + add_unit_number * now_price
#    367       144      12385.0     86.0      0.0              den = (cliped_unit_number + add_unit_number)
#    368       144      11906.0     82.7      0.0              new_mean_cost_price = num / den
#    369                                                   else:
#    370       275      20302.0     73.8      0.1              new_mean_cost_price = mean_cost_price  # 元のまま
#    371
#    372       419      68648.0    163.8      0.2          self.all_property = cash + now_price * unit_number * self.one_unit_stocks  # 全資産
#    373
#    374       419      28459.0     67.9      0.1          self.state = StockState(cash=new_cash,
#    375       419      46075.0    110.0      0.1                                  unit_number=new_unit_number,
#    376       419      36739.0     87.7      0.1                                  mean_cost_price=new_mean_cost_price,
#    377       419      99548.0    237.6      0.3                                  price_array=state_prices_array
#    378                                                                          )
#    379
#    380       419      35933.0     85.8      0.1          self.now_datetime = now_datetime
#    381
#    382       419      27767.0     66.3      0.1          self.info = {"datetime":self.now_datetime,
#    383       419      39128.0     93.4      0.1                       "stock_name":self.stock_name,
#    384       419      24637.0     58.8      0.1                       "done_action":action,
#    385       419      28048.0     66.9      0.1                       "all_property":self.all_property,
#    386       419      27472.0     65.6      0.1                       "penalty":penalty,
#    387       419      25475.0     60.8      0.1                       "gein_reward":gein_reward,
#    388       419      24862.0     59.3      0.1                       "price_reward":price_reward,
#    389       419      39776.0     94.9      0.1                       "reward":reward,
#    390                                                               }  # stock_nameを入れる意味ある？
#    391
#    392       419      30724.0     73.3      0.1          self.now_index = now_index
#    393       419      39831.0     95.1      0.1          self.step_counter += 1
#    394
#    395                                                   # doneの更新
#    396       419      42788.0    102.1      0.1          done = (self.step_counter >= self.episode_length) or (self.all_property < self.low_limmit)
#    397
#    398                                                   # エピソードが終了して，resetが呼ばれる前にstepが呼ばれた時のエラー判定
#    399       419      27912.0     66.6      0.1          if done:
#    400         1         26.0     26.0      0.0              if self.steps_beyond_done is None:
#    401         1         28.0     28.0      0.0                  self.steps_beyond_done = 0  # 0 に初期化
#    402
#    403                                                       elif self.steps_beyond_done == 0:  # 0の時のみロギング
#    404                                                           logger.warn(
#    405                                                               "You are calling 'step()' even though this "
#    406                                                               "environment has already returned done = True. You"
#    407                                                               "should always call 'reset()' once you receive 'done ="
#    408                                                               "True' -- any further steps are undefined behavior"
#    409                                                           )
#    410                                                           self.steps_beyond_done += 1
#    411
#    412       419     294138.0    702.0      0.8          return self.state.copy(), reward, done, self.info  # 一応stateをコピー
#
# Total time: 0.0054444 s
# File: <ipython-input-21-95c3085e6d70>
# Function: get_gein_reward at line 414
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    414                                               def get_gein_reward(self, now_price, add_unit_number):
#    415                                                   """
#    416                                                   株式の売却による利益を意味する報酬
#    417                                                   """
#    418       419      45139.0    107.7     82.9          gein_reward = now_price * self.one_unit_stocks * (- add_unit_number) # 買いがプラスであるため，マイナスをかける．cashの計算に利用する．
#    419       419       9305.0     22.2     17.1          return gein_reward
#
# Total time: 0.0047992 s
# File: <ipython-input-21-95c3085e6d70>
# Function: get_price_reward at line 421
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    421                                               def get_price_reward(self, now_price, mean_cost_price, add_unit_number):
#    422                                                   """
#    423                                                   平均取得価格と現在価格とその売買に関係する報酬
#    424                                                   """
#    425       419      35711.0     85.2     74.4          price_reward = (now_price - mean_cost_price) * self.one_unit_stocks * (- add_unit_number)
#    426       419      12281.0     29.3     25.6          return price_reward
#
# Total time: 0.0221119 s
# File: <ipython-input-21-95c3085e6d70>
# Function: get_trading_penalty at line 428
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    428                                               def get_trading_penalty(self, sell_condition_index, buy_condition_index, action):
#    429                                                   """
#    430                                                   売買条件を制限するペナルティ．
#    431                                                   """
#    432       419      16298.0     38.9      7.4          penalty = 0
#    433                                                   # 売買条件ペナルティ
#    434       419      26657.0     63.6     12.1          if action < self.stay_index:  # 売りの場合
#    435       275       9567.0     34.8      4.3              if action < sell_condition_index:  # 行動が最小条件より下になった場合
#    436       250     110295.0    441.2     49.9                  prepenalty = - (sell_condition_index - action) * self.initial_cash * 0.5
#    437       250      17198.0     68.8      7.8                  assert prepenalty <= 0,"this penalty must be minus {}".format(prepenalty)
#    438       250      19299.0     77.2      8.7                  penalty += prepenalty
#    439
#    440       144       5080.0     35.3      2.3          elif action > self.stay_index:  # 買いの場合
#    441       144       3997.0     27.8      1.8              if action > buy_condition_index:  # 行動が最大条件より上になった場合
#    442                                                           prepenalty = - (action - buy_condition_index) * self.initial_cash * 0.5
#    443                                                           assert prepenalty <= 0,"this penalty must be minus {}".format(prepenalty)
#    444                                                           penalty += prepenalty
#    445       419      12728.0     30.4      5.8          return penalty
#
# Total time: 0.0150289 s
# File: <ipython-input-21-95c3085e6d70>
# Function: get_stay_penalty at line 447
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    447                                               def get_stay_penalty(self, cash, action, unit_number):
#    448       419      15943.0     38.1     10.6          penalty = 0
#    449       419      13261.0     31.6      8.8          condition_list = []
#    450       419      25195.0     60.1     16.8          low_unit_stay_condition = action == self.stay_index and unit_number < self.stay_penalty_unit_bound  # 行動がステイかつユニット数が閾値以下の場合
#    451       419      20203.0     48.2     13.4          condition_list.append(low_unit_stay_condition)
#    452       419      19875.0     47.4     13.2          low_cash_stay_condition = action == self.stay_index and cash < self.stay_penalty_cash_bound  # 行動がステイかつ現金が閾値以下の場合
#    453       419      15862.0     37.9     10.6          condition_list.append(low_cash_stay_condition)
#    454
#    455       419      26235.0     62.6     17.5          if any(condition_list):  # 条件のどれかが当てはまる場合
#    456                                                       #prepenalty = cash * (-0.10)  # 現金のx%のペナルティ
#    457                                                       prepenalty = - self.initial_cash * (0.2)
#    458                                                       penalty += prepenalty
#    459       419      13715.0     32.7      9.1          return penalty
#
# Total time: 0 s
# File: <ipython-input-21-95c3085e6d70>
# Function: close at line 461
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    461                                               def close(self):
#    462                                                   """
#    463                                                   ビューのクローズとseedのリセット
#    464                                                   """
#    465                                                   if self.use_view:
#    466                                                       self.stock_view.close()
#    467                                                   self.seed(None)  # シードの初期化
#
# Total time: 0 s
# File: <ipython-input-21-95c3085e6d70>
# Function: seed at line 469
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    469                                               def seed(self, seed=None):
#    470                                                   """
#    471                                                   reset時のサンプリングのseedを設定する．リセットの場合，何も指定しないかNoneを指定
#    472                                                   """
#    473                                                   self.seed_number = seed
#
# Total time: 0 s
# File: <ipython-input-21-95c3085e6d70>
# Function: set_weight at line 475
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    475                                               def set_weight(self, gein_reward_weight=0, price_reward_weight=1, penalty_weight=1):
#    476                                                   self.gein_reward_weight = gein_reward_weight
#    477                                                   self.price_reward_weight = price_reward_weight
#    478                                                   self.penalty_weight = penalty_weight

# %% [markdown]
# #### メモリのプロファイリング

# %% [markdown]
# ### 学習

# %% [markdown]
# #### エージェント名

# %%
now_datetime = datetime.datetime.now()
now_str = now_datetime.strftime("%Y_%m_%d__%H_%M_%S")
agent_name = now_str

# %% [markdown]
# #### 画像を保存するディレクトリ

# %%
save_fig_dir_path = Path("tradng_process_figures") / Path(agent_name)
if not save_fig_dir_path.exists():
    save_fig_dir_path.mkdir()

# %% [markdown]
# #### 学習

# %%
# n_episodes = 300
n_episodes = 1000

# 学習


for i in tqdm(range(1, n_episodes + 1)):
    # seedのセッティング
    env.seed(0)
    #env.seed()
    
    # epsilonの減衰
    #epsilon = extinction_epsilon(i)
    #explorer = pfrl.explorers.ConstantEpsilonGreedy(epsilon=epsilon,
    #                                            random_action_func=env.action_space.sample
    #                                           )
    
    #agent.explorer = explorer
    
    obs,_,_,_ = env.reset()
    
    normalized_obs = state_transform(obs)
    #normalized_obs = obs
    
    R = 0
    t = 0
    train_action_list = []
    
    while True:
        action = agent.act(normalized_obs.to_numpy())
        train_action_list.append(action)  # action list についか
        obs, reward, done, info = env.step(action)

        R += reward
        t += 1
        reset = False  # リセットタイミングはdoneに依存
        # state, rewardの前処理
        normalized_obs = state_transform(obs)
        #normalized_reward = reward_transform(reward)
        #normalized_obs = obs
        normalized_reward = reward
        
        agent.observe(normalized_obs.to_numpy(), normalized_reward, done, reset)
        if done:
            break

    if i%10 == 0:
        print("episode:{}, return:{}, episode_length:{}".format(i, R, t))
        print("action_counter:",collections.Counter(train_action_list))
    if i%50 == 0:
        print("statistics:", agent.get_statistics())
        
    # テスト(イプシロンを無視)
    if i%50 == 0:
        state_list = []
        info_list = []
        with agent.eval_mode():
            # シードの設定
            env.seed()
            #env.seed(0)
            obs,_,_,info = env.reset()
            
            test_action_list = []
            
            normalized_obs = state_transform(obs)
            #normalized_obs = obs
            
            state_list.append(obs)
            info_list.append(info)
            
            R = 0
            t = 0
            
            print("\tt:{},all_property:{}, unit_number:{}, price:{}, penalty:{}, cash:{}".format(t,
                                                                                                 info["all_property"],
                                                                                                 obs.unit_number,
                                                                                                 obs.price_array[0],
                                                                                                 info["penalty"],
                                                                                                 obs.cash
                                                                                                ))
            while True:
                action = agent.act(normalized_obs.to_numpy())
                test_action_list.append(action)
                obs, reward, done, info = env.step(action)
                R += reward
                t += 1
                reset = False

                # state, rewardの前処理
                normalized_obs = state_transform(obs)
                #normalized_reward = reward_transform(reward)
                #normalized_obs = obs
                normalized_reward = reward
                
                state_list.append(obs)
                info_list.append(info)


                #agent.observe(normalized_obs.to_numpy(), normalized_reward, done, reset)
                if done or reset:
                    break
                if t%100==0:
                    print("\tt:{},all_property:{}, unit_number:{}, price:{}, penalty:{}, cash:{}".format(t,
                                                                                                         info["all_property"],
                                                                                                         obs.unit_number,
                                                                                                         obs.now_price,
                                                                                                         info["penalty"],
                                                                                                         obs.cash
                                                                                                        ))
                    print("\taction_counter:",collections.Counter(test_action_list))

        print("\tevaluation episode: {}, return:{}, episode_length:{}".format(i, R, t))
        print("\tall_property:", info["all_property"])
        print("\n")
        
        # 取引過程の描画
        save_image_path = save_fig_dir_path / Path("trading_process_i_{}.png".format(i))
        plot_trading_process_bokeh(state_list, info_list, env, save_path=save_image_path, is_save=True, is_html=False)

print("Finshed")
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# episode:10, return:-248358898.20493853, episode_length:419
# action_counter: Counter({7: 174, 4: 85, 6: 52, 8: 21, 3: 14, 1: 13, 10: 13, 2: 13, 9: 13, 0: 11, 5: 10})
# episode:20, return:-27254704.812248293, episode_length:419
# action_counter: Counter({4: 160, 6: 125, 8: 30, 7: 22, 1: 19, 0: 16, 9: 11, 5: 11, 10: 10, 3: 8, 2: 7})
# episode:30, return:-6372716.0970268985, episode_length:419
# action_counter: Counter({4: 190, 6: 118, 10: 20, 8: 15, 1: 15, 7: 13, 9: 13, 2: 13, 3: 9, 0: 7, 5: 6})
# episode:40, return:-9465726.162919248, episode_length:419
# action_counter: Counter({6: 154, 4: 151, 1: 17, 10: 16, 5: 14, 0: 13, 8: 12, 9: 12, 7: 11, 3: 10, 2: 9})
# episode:50, return:-34372067.37373203, episode_length:419
# action_counter: Counter({4: 192, 6: 116, 10: 22, 2: 15, 3: 13, 7: 13, 5: 12, 1: 11, 9: 10, 0: 9, 8: 6})
# statistics: [('average_q', -10790.636), ('average_loss', 177886.21044921875), ('cumulative_steps', 20950), ('n_updates', 20451), ('rlen', 20950)]
# 	t:0,all_property:3646000.0, unit_number:50, price:2646.0, penalty:0, cash:1000000.0
# 	t:100,all_property:3641340.0, unit_number:-50, price:2654.0, penalty:-500000.0, cash:6295340.0
# 	action_counter: Counter({4: 100})
# 	t:200,all_property:3414060.0, unit_number:-150, price:2745.0, penalty:-500000.0, cash:11649060.0
# 	action_counter: Counter({4: 200})
# 	t:300,all_property:3258680.0, unit_number:-250, price:2782.0, penalty:-500000.0, cash:17168680.0
# 	action_counter: Counter({4: 300})
# 	t:400,all_property:3440880.0, unit_number:-350, price:2752.0, penalty:-500000.0, cash:22704880.0
# 	action_counter: Counter({4: 400})
# 	evaluation episode: 50, return:-183921800.0, episode_length:419
# 	all_property: 3530480.0
#
#
# episode:60, return:-25434131.900193293, episode_length:419
# action_counter: Counter({4: 168, 6: 142, 1: 16, 9: 16, 2: 15, 5: 14, 0: 11, 3: 10, 8: 9, 10: 9, 7: 9})
# episode:70, return:-43535768.56639392, episode_length:419
# action_counter: Counter({4: 187, 6: 125, 3: 16, 5: 15, 10: 14, 8: 12, 1: 12, 0: 11, 9: 10, 7: 9, 2: 8})
# episode:80, return:-48247854.29500604, episode_length:419
# action_counter: Counter({4: 157, 6: 148, 2: 22, 0: 18, 9: 16, 10: 12, 7: 10, 8: 9, 5: 9, 3: 9, 1: 9})
# episode:90, return:-28016316.141263846, episode_length:419
# action_counter: Counter({4: 168, 6: 153, 3: 17, 9: 16, 0: 15, 10: 12, 2: 10, 1: 9, 5: 7, 7: 7, 8: 5})
# episode:100, return:-5944930.324583355, episode_length:419
# action_counter: Counter({4: 160, 6: 159, 5: 15, 9: 14, 3: 13, 1: 10, 7: 10, 2: 10, 0: 10, 8: 9, 10: 9})
# statistics: [('average_q', -30078.56), ('average_loss', 93730.33166992187), ('cumulative_steps', 41900), ('n_updates', 41401), ('rlen', 41900)]
# 	t:0,all_property:2082000.0, unit_number:50, price:1082.0, penalty:0, cash:1000000.0
# 	t:100,all_property:2158580.0, unit_number:56, price:1123.0, penalty:0, cash:900820.0
# 	action_counter: Counter({6: 53, 4: 47})
# 	t:200,all_property:2151340.0, unit_number:32, price:1102.0, penalty:0, cash:1446060.0
# 	action_counter: Counter({4: 109, 6: 91})
# 	t:300,all_property:2156540.0, unit_number:2, price:1082.0, penalty:0, cash:2113260.0
# 	action_counter: Counter({4: 174, 6: 126})
# 	t:400,all_property:2152880.0, unit_number:-6, price:1115.0, penalty:0, cash:2286680.0
# 	action_counter: Counter({4: 228, 6: 172})
# 	evaluation episode: 100, return:-48414137.6718649, episode_length:419
# 	all_property: 2151800.0
#
#
# episode:110, return:-21053844.946512956, episode_length:419
# action_counter: Counter({6: 161, 4: 161, 8: 15, 3: 14, 7: 13, 10: 12, 5: 10, 2: 10, 0: 9, 9: 7, 1: 7})
# episode:120, return:-18447480.715667233, episode_length:419
# action_counter: Counter({4: 168, 6: 141, 8: 18, 1: 17, 2: 13, 10: 13, 7: 12, 5: 12, 9: 9, 0: 9, 3: 7})
# episode:130, return:-20939677.92954048, episode_length:419
# action_counter: Counter({6: 166, 4: 144, 3: 16, 1: 16, 2: 16, 8: 13, 0: 11, 9: 10, 10: 10, 7: 9, 5: 8})
# episode:140, return:-25029905.863339383, episode_length:419
# action_counter: Counter({4: 174, 6: 131, 5: 19, 7: 16, 8: 13, 1: 13, 2: 13, 3: 12, 10: 11, 0: 9, 9: 8})
# episode:150, return:-28646248.616411448, episode_length:419
# action_counter: Counter({4: 183, 6: 97, 7: 48, 10: 17, 8: 14, 1: 13, 9: 12, 5: 12, 0: 10, 3: 7, 2: 6})
# statistics: [('average_q', -39685.832), ('average_loss', 62538.003822021485), ('cumulative_steps', 62850), ('n_updates', 62351), ('rlen', 62850)]
# 	t:0,all_property:3644000.0, unit_number:50, price:2644.0, penalty:0, cash:1000000.0
# 	t:100,all_property:3758280.0, unit_number:48, price:2755.0, penalty:0, cash:1113480.0
# 	action_counter: Counter({6: 62, 4: 25, 2: 13})
# 	t:200,all_property:3808140.0, unit_number:52, price:2797.0, penalty:0, cash:899260.0
# 	action_counter: Counter({6: 129, 4: 44, 2: 26, 0: 1})
# 	t:300,all_property:3751240.0, unit_number:60, price:2740.0, penalty:0, cash:463240.0
# 	action_counter: Counter({6: 186, 4: 84, 2: 29, 0: 1})
# 	t:400,all_property:3721800.0, unit_number:56, price:2716.0, penalty:0, cash:679880.0
# 	action_counter: Counter({6: 242, 4: 120, 2: 37, 0: 1})
# 	evaluation episode: 150, return:15717.386210562894, episode_length:419
# 	all_property: 3846040.0
#
#
# episode:160, return:-13938112.544149533, episode_length:419
# action_counter: Counter({4: 183, 6: 82, 7: 51, 1: 17, 8: 14, 10: 13, 2: 13, 9: 13, 3: 13, 0: 12, 5: 8})
# episode:170, return:-40332128.521575995, episode_length:419
# action_counter: Counter({4: 179, 6: 80, 7: 64, 0: 16, 5: 15, 2: 12, 1: 12, 10: 11, 3: 11, 9: 10, 8: 9})
# episode:180, return:-61938674.95228643, episode_length:419
# action_counter: Counter({4: 222, 6: 69, 7: 57, 8: 13, 0: 11, 1: 9, 10: 9, 3: 8, 9: 8, 2: 7, 5: 6})
# episode:190, return:-23932167.980008885, episode_length:419
# action_counter: Counter({4: 208, 7: 104, 6: 19, 1: 15, 5: 15, 8: 14, 9: 12, 2: 12, 0: 9, 3: 8, 10: 3})
# episode:200, return:-48369682.977131754, episode_length:419
# action_counter: Counter({4: 186, 7: 112, 6: 32, 3: 19, 0: 13, 10: 13, 5: 11, 9: 11, 8: 8, 2: 7, 1: 7})
# statistics: [('average_q', -52444.816), ('average_loss', 52816.28967773438), ('cumulative_steps', 83800), ('n_updates', 83301), ('rlen', 83800)]
# 	t:0,all_property:3780000.0, unit_number:50, price:2780.0, penalty:0, cash:1000000.0
# 	t:100,all_property:3762540.0, unit_number:22, price:2753.0, penalty:0, cash:2551220.0
# 	action_counter: Counter({6: 69, 0: 16, 4: 14, 2: 1})
# 	t:200,all_property:3750280.0, unit_number:32, price:2724.0, penalty:0, cash:2006920.0
# 	action_counter: Counter({6: 154, 0: 31, 4: 14, 2: 1})
# 	t:300,all_property:3774900.0, unit_number:24, price:2778.0, penalty:0, cash:2441460.0
# 	action_counter: Counter({6: 236, 0: 49, 4: 14, 2: 1})
# 	t:400,all_property:3808720.0, unit_number:22, price:2844.0, penalty:0, cash:2557360.0
# 	action_counter: Counter({6: 319, 0: 66, 4: 14, 2: 1})
# 	evaluation episode: 200, return:1300.5260341975281, episode_length:419
# 	all_property: 3808340.0
#
#
# episode:210, return:-48027738.02624762, episode_length:419
# action_counter: Counter({4: 140, 2: 82, 7: 48, 8: 43, 6: 30, 9: 22, 10: 17, 5: 11, 0: 9, 3: 9, 1: 8})
# episode:220, return:-83605449.19383134, episode_length:419
# action_counter: Counter({4: 103, 2: 80, 6: 56, 8: 52, 7: 32, 9: 26, 0: 15, 5: 15, 10: 14, 3: 13, 1: 13})
# episode:230, return:-87620396.19704199, episode_length:419
# action_counter: Counter({2: 89, 4: 83, 8: 67, 6: 59, 9: 44, 7: 16, 0: 15, 3: 14, 5: 12, 1: 11, 10: 9})
# episode:240, return:-56519046.50796545, episode_length:419
# action_counter: Counter({2: 117, 8: 68, 9: 62, 4: 51, 6: 40, 3: 18, 5: 16, 0: 16, 10: 13, 7: 9, 1: 9})
# episode:250, return:-52593781.18682142, episode_length:419
# action_counter: Counter({2: 132, 9: 83, 4: 57, 8: 39, 6: 28, 3: 23, 7: 15, 1: 13, 5: 11, 0: 9, 10: 9})
# statistics: [('average_q', -62678.367), ('average_loss', 61838.33974121094), ('cumulative_steps', 104750), ('n_updates', 104251), ('rlen', 104750)]
# 	t:0,all_property:2039000.0, unit_number:50, price:1039.0, penalty:0, cash:1000000.0
# 	t:100,all_property:2139980.0, unit_number:31, price:1103.0, penalty:0, cash:1456120.0
# 	action_counter: Counter({2: 49, 9: 31, 4: 13, 8: 5, 6: 2})
# 	t:200,all_property:2128740.0, unit_number:83, price:1083.0, penalty:0, cash:330960.0
# 	action_counter: Counter({2: 94, 9: 75, 4: 13, 6: 13, 8: 5})
# 	t:300,all_property:2143260.0, unit_number:5, price:1130.0, penalty:0, cash:2030260.0
# 	action_counter: Counter({2: 156, 9: 99, 6: 22, 4: 16, 8: 7})
# 	t:400,all_property:2143080.0, unit_number:4, price:1102.0, penalty:0, cash:2054920.0
# 	action_counter: Counter({2: 209, 9: 136, 6: 32, 4: 16, 8: 7})
# 	evaluation episode: 250, return:-41332568.55663017, episode_length:419
# 	all_property: 2141720.0
#
#
# episode:260, return:-87302685.37926412, episode_length:419
# action_counter: Counter({4: 102, 2: 99, 9: 93, 8: 33, 3: 20, 6: 17, 10: 13, 7: 13, 1: 12, 5: 9, 0: 8})
# episode:270, return:-27085526.706879247, episode_length:419
# action_counter: Counter({2: 133, 9: 115, 4: 57, 6: 23, 8: 21, 3: 17, 7: 13, 1: 12, 0: 10, 10: 10, 5: 8})
# episode:280, return:-21300899.430181682, episode_length:419
# action_counter: Counter({2: 137, 9: 98, 4: 41, 7: 34, 8: 28, 6: 25, 0: 17, 1: 14, 10: 13, 5: 7, 3: 5})
# episode:290, return:-73708477.73177898, episode_length:419
# action_counter: Counter({9: 112, 2: 106, 4: 53, 3: 35, 6: 33, 1: 19, 7: 18, 8: 13, 10: 12, 0: 10, 5: 8})
# episode:300, return:-48790822.9904283, episode_length:419
# action_counter: Counter({9: 116, 2: 109, 4: 59, 6: 48, 1: 21, 5: 14, 3: 13, 0: 12, 7: 10, 10: 10, 8: 7})
# statistics: [('average_q', -73480.92), ('average_loss', 62766.643703613285), ('cumulative_steps', 125700), ('n_updates', 125201), ('rlen', 125700)]
# 	t:0,all_property:2042000.0, unit_number:50, price:1042.0, penalty:0, cash:1000000.0
# 	t:100,all_property:2145140.0, unit_number:45, price:1101.0, penalty:0, cash:1154240.0
# 	action_counter: Counter({2: 46, 9: 35, 4: 13, 6: 6})
# 	t:200,all_property:2112860.0, unit_number:95, price:1081.0, penalty:0, cash:58960.0
# 	action_counter: Counter({9: 70, 2: 70, 4: 36, 6: 16, 3: 6, 10: 1, 7: 1})
# 	t:300,all_property:2191120.0, unit_number:-18, price:1129.0, penalty:0, cash:2597560.0
# 	action_counter: Counter({2: 113, 9: 82, 4: 71, 6: 21, 3: 9, 7: 3, 10: 1})
# 	t:400,all_property:2242580.0, unit_number:71, price:1131.0, penalty:0, cash:636560.0
# 	action_counter: Counter({2: 130, 9: 117, 4: 94, 6: 44, 3: 10, 7: 4, 10: 1})
# 	evaluation episode: 300, return:-49230127.5357963, episode_length:419
# 	all_property: 2236020.0
#
#
# episode:310, return:-27072251.870120283, episode_length:419
# action_counter: Counter({2: 139, 9: 126, 6: 27, 4: 27, 3: 21, 8: 17, 5: 16, 0: 16, 7: 14, 1: 9, 10: 7})
# episode:320, return:-58691816.57059955, episode_length:419
# action_counter: Counter({9: 109, 2: 97, 4: 97, 6: 34, 3: 17, 1: 14, 10: 12, 7: 11, 0: 10, 8: 10, 5: 8})
# episode:330, return:-87679339.72049123, episode_length:419
# action_counter: Counter({2: 97, 9: 88, 4: 82, 6: 56, 10: 18, 1: 17, 7: 17, 3: 15, 8: 12, 0: 10, 5: 7})
# episode:340, return:-44502987.06044307, episode_length:419
# action_counter: Counter({9: 118, 2: 114, 4: 83, 6: 37, 5: 16, 3: 14, 10: 10, 0: 9, 1: 9, 7: 5, 8: 4})
# episode:350, return:-83878524.32629058, episode_length:419
# action_counter: Counter({2: 151, 9: 110, 6: 49, 4: 28, 8: 18, 3: 13, 1: 11, 5: 11, 10: 11, 7: 10, 0: 7})
# statistics: [('average_q', -71833.18), ('average_loss', 68021.28123046875), ('cumulative_steps', 146650), ('n_updates', 146151), ('rlen', 146650)]
# 	t:0,all_property:3626000.0, unit_number:50, price:2626.0, penalty:0, cash:1000000.0
# 	t:100,all_property:3636100.0, unit_number:34, price:2641.0, penalty:0, cash:1840220.0
# 	action_counter: Counter({5: 92, 4: 6, 0: 2})
# 	t:200,all_property:3643300.0, unit_number:31, price:2652.0, penalty:0, cash:1999060.0
# 	action_counter: Counter({5: 189, 4: 9, 0: 2})
# 	t:300,all_property:3722660.0, unit_number:31, price:2780.0, penalty:0, cash:1999060.0
# 	action_counter: Counter({5: 289, 4: 9, 0: 2})
# 	t:400,all_property:3723900.0, unit_number:31, price:2782.0, penalty:0, cash:1999060.0
# 	action_counter: Counter({5: 389, 4: 9, 0: 2})
# 	evaluation episode: 350, return:1180.0, episode_length:419
# 	all_property: 3726380.0
#
#
# episode:360, return:-49963674.410509266, episode_length:419
# action_counter: Counter({9: 111, 2: 106, 4: 64, 6: 41, 0: 19, 3: 16, 8: 15, 1: 14, 7: 12, 5: 11, 10: 10})
# episode:370, return:-31085680.119343113, episode_length:419
# action_counter: Counter({2: 129, 9: 102, 4: 59, 6: 42, 7: 16, 5: 16, 10: 14, 8: 13, 0: 10, 1: 10, 3: 8})
# episode:380, return:-42470030.02317584, episode_length:419
# action_counter: Counter({9: 112, 2: 111, 4: 73, 6: 39, 8: 15, 3: 14, 0: 13, 5: 12, 1: 12, 10: 10, 7: 8})
# episode:390, return:-71773568.38780521, episode_length:419
# action_counter: Counter({9: 108, 4: 99, 6: 64, 0: 47, 2: 39, 1: 14, 3: 13, 7: 11, 8: 9, 5: 8, 10: 7})
# episode:400, return:-31395252.33336662, episode_length:419
# action_counter: Counter({9: 116, 2: 77, 4: 70, 0: 47, 6: 44, 10: 12, 8: 12, 1: 12, 7: 12, 3: 9, 5: 8})
# statistics: [('average_q', -88749.42), ('average_loss', 60348.29371459961), ('cumulative_steps', 167600), ('n_updates', 167101), ('rlen', 167600)]
# 	t:0,all_property:2021000.0, unit_number:50, price:1021.0, penalty:0, cash:1000000.0
# 	t:100,all_property:2057960.0, unit_number:95, price:1040.0, penalty:0, cash:81960.0
# 	action_counter: Counter({4: 68, 9: 27, 6: 5})
# 	t:200,all_property:2140120.0, unit_number:43, price:1080.0, penalty:0, cash:1211320.0
# 	action_counter: Counter({4: 105, 9: 45, 2: 33, 6: 17})
# 	t:300,all_property:2166460.0, unit_number:97, price:1099.0, penalty:0, cash:34400.0
# 	action_counter: Counter({4: 123, 9: 87, 2: 58, 6: 26, 0: 6})
# 	t:400,all_property:2217960.0, unit_number:67, price:1128.0, penalty:0, cash:706440.0
# 	action_counter: Counter({4: 178, 9: 91, 2: 63, 6: 60, 0: 8})
# 	evaluation episode: 400, return:-5303228.604238659, episode_length:419
# 	all_property: 2221140.0
#
#
# episode:410, return:-46771921.183768295, episode_length:419
# action_counter: Counter({9: 131, 2: 106, 4: 68, 0: 26, 5: 15, 6: 14, 1: 14, 3: 14, 7: 12, 8: 10, 10: 9})
# episode:420, return:-42907647.96594771, episode_length:419
# action_counter: Counter({2: 120, 9: 106, 4: 80, 6: 21, 8: 18, 7: 17, 3: 15, 10: 13, 1: 10, 0: 10, 5: 9})
# episode:430, return:-42504578.33740395, episode_length:419
# action_counter: Counter({9: 103, 2: 99, 4: 89, 6: 43, 7: 15, 1: 15, 5: 12, 10: 11, 8: 11, 0: 11, 3: 10})
# episode:440, return:-52796689.018176295, episode_length:419
# action_counter: Counter({2: 145, 9: 123, 4: 38, 6: 28, 7: 15, 3: 14, 10: 13, 1: 13, 8: 12, 0: 11, 5: 7})
# episode:450, return:-46899516.36832249, episode_length:419
# action_counter: Counter({9: 104, 4: 99, 2: 94, 6: 33, 0: 16, 10: 14, 3: 14, 7: 14, 8: 12, 1: 11, 5: 8})
# statistics: [('average_q', -93631.77), ('average_loss', 70818.19772460937), ('cumulative_steps', 188550), ('n_updates', 188051), ('rlen', 188550)]
# 	t:0,all_property:2107000.0, unit_number:50, price:1107.0, penalty:0, cash:1000000.0
# 	t:100,all_property:2060440.0, unit_number:100, price:1092.0, penalty:0, cash:-123560.0
# 	action_counter: Counter({9: 43, 2: 39, 4: 12, 6: 5, 7: 1})
# 	t:200,all_property:2120820.0, unit_number:10, price:1121.0, penalty:0, cash:1896620.0
# 	action_counter: Counter({2: 88, 9: 59, 4: 33, 6: 19, 7: 1})
# 	t:300,all_property:2085340.0, unit_number:99, price:1100.0, penalty:0, cash:-92660.0
# 	action_counter: Counter({2: 93, 9: 92, 4: 78, 6: 36, 7: 1})
# 	t:400,all_property:2123740.0, unit_number:52, price:1123.0, penalty:0, cash:955820.0
# 	action_counter: Counter({4: 144, 2: 105, 9: 105, 6: 44, 7: 1, 0: 1})
# 	evaluation episode: 450, return:-74899410.60287276, episode_length:419
# 	all_property: 2130420.0
#
#
# episode:460, return:-68612362.68841167, episode_length:419
# action_counter: Counter({2: 111, 9: 94, 4: 78, 6: 32, 0: 20, 7: 19, 10: 18, 1: 16, 8: 14, 3: 10, 5: 7})
# episode:470, return:-81926646.79234913, episode_length:419
# action_counter: Counter({9: 92, 0: 80, 4: 61, 2: 39, 6: 38, 10: 37, 7: 20, 3: 14, 1: 14, 5: 12, 8: 12})

# %% [markdown]
# ###  モデルの評価

# %%
with agent.eval_mode():
    env.seed()
    #env.seed(0)
    for i in range(10):
        obs,_,_,_ = env.reset()
        R = 0
        t = 1
        
        normalized_obs = state_transform(obs)
        #normalized_obs = obs
        
        while True:
            action = agent.act(normalized_obs.to_numpy())
            obs, reward, done, info = env.step(action)
            R += reward
            t += 1
            reset = False

            # state, rewardの前処理
            normalized_obs = state_transform(obs)
            #normalized_reward = reward_transform(reward)
            #normalized_obs = obs
            normalized_reward = reward


            #agent.observe(normalized_obs.to_numpy(), normalized_reward, done, reset)
            if done or reset:
                break
        
        print("evaluation episode: {}, return:{}, episode_length:{}".format(i, R, t))
        print("all_property:", env.all_property)

# %% [markdown]
# ###  売買過程の描画

# %% [markdown]
# #### 一度に描画

# %%
state_list = []
info_list = []
test_action_list = []


with agent.eval_mode():
    env.seed()
    #env.seed(0)
    obs,_,_,info = env.reset()

    state_list.append(obs)
    info_list.append(info)
    R = 0
    t = 1
    print("\tt:{},all_property:{}, unit_number:{}, price:{}, penalty:{}, cash:{}".format(t,
                                                                                         info["all_property"],
                                                                                         obs.unit_number,
                                                                                         obs.now_price,
                                                                                         info["penalty"],
                                                                                         obs.cash
                                                                                        ))
    
    normalized_obs = state_transform(obs)
    #normalized_obs = obs

    while True:
        action = agent.act(normalized_obs.to_numpy())
        test_action_list.append(action)
        obs, reward, done, info = env.step(action)
        R += reward
        t += 1
        reset = False


        # state, rewardの前処理
        normalized_obs = state_transform(obs)
        #normalized_reward = reward_transform(reward)
        #normalized_obs = obs
        normalized_reward = reward

        agent.observe(normalized_obs.to_numpy(), normalized_reward, done, reset)
        
        state_list.append(obs)
        info_list.append(info)
        
        if done or reset:
            break
        if t%100==0:
            print("\tt:{},all_property:{}, unit_number:{}, price:{}, penalty:{}, cash:{}".format(t,
                                                                                                 info["all_property"],
                                                                                                 obs.unit_number,
                                                                                                 obs.now_price,
                                                                                                 info["penalty"],
                                                                                                 obs.cash
                                                                                                ))
            print("\taction_counter:",collections.Counter(test_action_list))
            
print("finishet. episode length: {}".format(t))

# %% [markdown]
# matplotlibで描画

# %%
plot_trading_process_bokeh(state_list, info_list, env, is_save=False)

# %% [markdown]
# ### 環境のクローズ

# %%
env.close()

# %% [markdown]
# ### モデルの保存

# %%
agent.save(Path("agents")/Path(agent_name))
print(agent_name)
